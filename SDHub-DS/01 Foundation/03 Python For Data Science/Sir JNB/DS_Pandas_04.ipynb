# %%
import pandas as pd

# %%
df = pd.DataFrame({'Name':['Uwaish','Aisha','Sayeeda','Khan','Raja'],
                  'Age':[22,23,24,32,22],
                  'Salary':[100,200,300,400,500],
                  'Role':['DS','DA','AI','DS','DA']})

df
# Out:
#       Name  Age  Salary Role
# 0   Uwaish   22     100   DS
# 1    Aisha   23     200   DA
# 2  Sayeeda   24     300   AI
# 3     Khan   32     400   DS
# 4     Raja   22     500   DA

# %%
# display first row

df.iloc[0]
# Out:
# Name      Uwaish
# Age           22
# Salary       100
# Role          DS
# Name: 0, dtype: object

# %%
# display first columns

df.iloc[:,0]
# Out:
# 0     Uwaish
# 1      Aisha
# 2    Sayeeda
# 3       Khan
# 4       Raja
# Name: Name, dtype: object

# %%
df2 = df.set_index('Name')

df2
# Out:
#          Age  Salary Role
# Name
# Uwaish    22     100   DS
# Aisha     23     200   DA
# Sayeeda   24     300   AI
# Khan      32     400   DS
# Raja      22     500   DA

# %%
# display Aisha record

df2.loc['Aisha']
# Out:
# Age        23
# Salary    200
# Role       DA
# Name: Aisha, dtype: object

# %%
# display Salary column

df2.loc[:,'Salary']
# Out:
# Name
# Uwaish     100
# Aisha      200
# Sayeeda    300
# Khan       400
# Raja       500
# Name: Salary, dtype: int64

# %% [markdown]
# **WAP to create a dataframe of your choice and then display first row, first col, and first two rows, first two columns**, emp_id, role and salary. use loc[]

# %%
df = pd.DataFrame({'Emp_id':[101,102,103,104,105],
                  'Role':['DS','DA','AI','DS','DA'],
                  'Salary':[100,200,300,400,500]})

df
# Out:
#    Emp_id Role  Salary
# 0     101   DS     100
# 1     102   DA     200
# 2     103   AI     300
# 3     104   DS     400
# 4     105   DA     500

# %%
df.loc[0]
# Out:
# Emp_id    101
# Role       DS
# Salary    100
# Name: 0, dtype: object

# %%
df.loc[:,'Emp_id']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# Name: Emp_id, dtype: int64

# %%
df.loc[0:1]
# Out:
#    Emp_id Role  Salary
# 0     101   DS     100
# 1     102   DA     200

# %%
df.loc[:,'Emp_id':'Role']
# Out:
#    Emp_id Role
# 0     101   DS
# 1     102   DA
# 2     103   AI
# 3     104   DS
# 4     105   DA

# %%
# display those employee id whose role is DA

df[df['Role']=='DA']
# Out:
#    Emp_id Role  Salary
# 1     102   DA     200
# 4     105   DA     500

# %%
df.loc[df['Role']=='DA','Emp_id']
# Out:
# 1    102
# 4    105
# Name: Emp_id, dtype: int64

# %%
# display emp_id where salary is above 200

df.loc[df['Salary']>200,'Emp_id']
# Out:
# 2    103
# 3    104
# 4    105
# Name: Emp_id, dtype: int64

# %% [markdown]
# ## Working with dataframes

# %%
df = pd.read_csv('FinData.csv')
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 676    Small Business                    France   Amarilla          High
# 677    Small Business                    Mexico   Amarilla          High
# 678        Government                    Mexico    Montana          High
# 679        Government                    Canada      Paseo          High
# 680  Channel Partners  United States of America        VTT          High
#
#      Product Cost  Units Sold  Sale Price  Gross Sales  Discounts      Sales  \
# ...

# %%
# get information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681 entries, 0 to 680
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Segment        681 non-null    object
#  1   Country        681 non-null    object
#  2   Product        681 non-null    object
#  3   Discount Band  628 non-null    object
#  4   Product Cost   681 non-null    int64
#  5   Units Sold     681 non-null    float64
#  6   Sale Price     681 non-null    int64
#  7   Gross Sales    681 non-null    float64
#  8   Discounts      681 non-null    float64
#  9    Sales         681 non-null    float64
#  10  COGS           681 non-null    float64
#  11  Profit         681 non-null    float64
#  12  Date           681 non-null    object
#  13  Month Number   681 non-null    int64
#  14  Month Name     681 non-null    object
#  15  Year           681 non-null    int64
# dtypes: float64(6), int64(4), object(6)
# memory usage: 85.3+ KB

# %%
# top 5 records

df.head()
# Out:
#       Segment  Country    Product Discount Band  Product Cost  Units Sold  \
# 0  Government   Canada  Carretera           NaN             3      1618.5
# 1  Government  Germany  Carretera           NaN             3      1321.0
# 2   Midmarket   France  Carretera           NaN             3      2178.0
# 3   Midmarket  Germany  Carretera           NaN             3       888.0
# 4   Midmarket   Mexico  Carretera           NaN             3      2470.0
#
#    Sale Price  Gross Sales  Discounts    Sales     COGS   Profit        Date  \
# 0          20      32370.0        0.0  32370.0  16185.0  16185.0  01-01-2023
# 1          20      26420.0        0.0  26420.0  13210.0  13210.0  01-01-2023
# 2          15      32670.0        0.0  32670.0  21780.0  10890.0  01-06-2023
# 3          15      13320.0        0.0  13320.0   8880.0   4440.0  01-06-2023
# 4          15      37050.0        0.0  37050.0  24700.0  12350.0  01-06-2023
#
#    Month Number Month Name  Year
# ...

# %%
df.head(2)
# Out:
#       Segment  Country    Product Discount Band  Product Cost  Units Sold  \
# 0  Government   Canada  Carretera           NaN             3      1618.5
# 1  Government  Germany  Carretera           NaN             3      1321.0
#
#    Sale Price  Gross Sales  Discounts    Sales     COGS   Profit        Date  \
# 0          20      32370.0        0.0  32370.0  16185.0  16185.0  01-01-2023
# 1          20      26420.0        0.0  26420.0  13210.0  13210.0  01-01-2023
#
#    Month Number Month Name  Year
# 0             1    January  2023
# 1             1    January  2023

# %%
df.tail(3)
# Out:
#               Segment                   Country  Product Discount Band  \
# 678        Government                    Mexico  Montana          High
# 679        Government                    Canada    Paseo          High
# 680  Channel Partners  United States of America      VTT          High
#
#      Product Cost  Units Sold  Sale Price  Gross Sales  Discounts     Sales  \
# 678             5      1368.0           7       9576.0    1436.40   8139.60
# 679            10       723.0           7       5061.0     759.15   4301.85
# 680           250      1806.0          12      21672.0    3250.80  18421.20
#
#        COGS    Profit        Date  Month Number Month Name  Year
# 678  6840.0   1299.60  01-02-2023             2   February  2023
# 679  3615.0    686.85  01-04-2023             4      April  2023
# 680  5418.0  13003.20  01-05-2023             5        May  2023

# %%
# display all comumn name

df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Product Cost',
#        'Units Sold', 'Sale Price', 'Gross Sales', 'Discounts', ' Sales',
#        'COGS', 'Profit', 'Date', 'Month Number', 'Month Name', 'Year'],
#       dtype='object')

# %%
# display datatypes

df.dtypes
# Out:
# Segment           object
# Country           object
# Product           object
# Discount Band     object
# Product Cost       int64
# Units Sold       float64
# Sale Price         int64
# Gross Sales      float64
# Discounts        float64
#  Sales           float64
# COGS             float64
# Profit           float64
# Date              object
# Month Number       int64
# Month Name        object
# Year               int64
# dtype: object

# %%
# get stats for numerical columns

df.describe()
# Out:
#        Product Cost   Units Sold  Sale Price   Gross Sales      Discounts  \
# count    681.000000   681.000000  681.000000  6.810000e+02     681.000000
# mean      97.543319  1611.983847  119.951542  1.857511e+05   13222.929457
# std      108.563623   867.511517  137.239043  2.563787e+05   23110.336950
# min        3.000000   200.000000    7.000000  1.799000e+03       0.000000
# 25%        5.000000   905.000000   12.000000  1.740900e+04     798.280000
# 50%       10.000000  1545.000000   20.000000  3.850500e+04    2559.600000
# 75%      250.000000  2234.000000  300.000000  2.877000e+05   16086.000000
# max      260.000000  4492.500000  350.000000  1.207500e+06  149677.500000
#
#               Sales           COGS         Profit  Month Number         Year
# count  6.810000e+02     681.000000     681.000000    681.000000   681.000000
# mean   1.725285e+05  147909.133627   24619.428106      7.885463  2022.750367
# ...

# %%
# display categorical data stats

df.describe(include='object')
# Out:
#            Segment Country Product Discount Band        Date Month Name
# count          681     681     681           628         681        681
# unique           5       5       6             3          16         12
# top     Government  Canada   Paseo        Medium  01-06-2023    October
# freq           292     138     198           242          70        134

# %%
# display total profit

df['Profit'].sum()
# Out:
# 16765830.54

# %%
# display average profit

df['Profit'].mean()
# Out:
# 24619.42810572687

# %%
# display min profit

df['Profit'].min()
# Out:
# -40617.5

# %%
# display total profit for Montana Product

df2 = df[df['Product']=='Montana']

df2['Profit'].sum()
# Out:
# 2111400.1

# %%
df[df['Product']=='Montana']['Profit'].sum()
# Out:
# 2111400.1

# %%
# display average gross sales for VTT product

df[df['Product']=='VTT']['Gross Sales'].mean()
# Out:
# 203394.19907407407

# %%
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 676    Small Business                    France   Amarilla          High
# 677    Small Business                    Mexico   Amarilla          High
# 678        Government                    Mexico    Montana          High
# 679        Government                    Canada      Paseo          High
# 680  Channel Partners  United States of America        VTT          High
#
#      Product Cost  Units Sold  Sale Price  Gross Sales  Discounts      Sales  \
# ...

# %%
df2 = df.sort_values('Profit')   # ascending order

df2
# Out:
#         Segment                   Country    Product Discount Band  \
# 673  Enterprise                    Canada        VTT          High
# 648  Enterprise                   Germany  Carretera          High
# 640  Enterprise  United States of America   Amarilla          High
# 612  Enterprise                    Mexico  Carretera          High
# 667  Enterprise  United States of America       Velo          High
# ..          ...                       ...        ...           ...
# 125  Government                   Germany       Velo           Low
# 124  Government                   Germany       Velo           Low
# 140  Government                   Germany   Amarilla           Low
# 45   Government                    France   Amarilla           NaN
# 192  Government  United States of America      Paseo           Low
#
#      Product Cost  Units Sold  Sale Price  Gross Sales  Discounts       Sales  \
# 673           250      2954.0         125     369250.0   55387.50   313862.50
# ...

# %%
# display top 3 rows absed on prfoit

df2.tail(3)
# Out:
#         Segment                   Country   Product Discount Band  \
# 140  Government                   Germany  Amarilla           Low
# 45   Government                    France  Amarilla           NaN
# 192  Government  United States of America     Paseo           Low
#
#      Product Cost  Units Sold  Sale Price  Gross Sales  Discounts      Sales  \
# 140           260      2966.0         350    1038100.0    20762.0  1017338.0
# 45            260      2750.0         350     962500.0        0.0   962500.0
# 192            10      3450.0         350    1207500.0    48300.0  1159200.0
#
#          COGS    Profit        Date  Month Number Month Name  Year
# 140  771160.0  246178.0  01-10-2022            10    October  2022
# 45   715000.0  247500.0  01-02-2023             2   February  2023
# 192  897000.0  262200.0  01-07-2023             7       July  2023

# %%
df.sort_values('Profit',ascending=False)   # descending order
# Out:
#         Segment                   Country    Product Discount Band  \
# 192  Government  United States of America      Paseo           Low
# 45   Government                    France   Amarilla           NaN
# 124  Government                   Germany       Velo           Low
# 140  Government                   Germany   Amarilla           Low
# 133  Government                   Germany        VTT           Low
# ..          ...                       ...        ...           ...
# 667  Enterprise  United States of America       Velo          High
# 612  Enterprise                    Mexico  Carretera          High
# 640  Enterprise  United States of America   Amarilla          High
# 648  Enterprise                   Germany  Carretera          High
# 673  Enterprise                    Canada        VTT          High
#
#      Product Cost  Units Sold  Sale Price  Gross Sales  Discounts       Sales  \
# 192            10      3450.0         350    1207500.0   48300.00  1159200.00
# ...

# %%
df2 = df[df['Country']=='Canada']
# Out:
#               Segment Country    Product Discount Band  Product Cost  \
# 0          Government  Canada  Carretera           NaN             3
# 7    Channel Partners  Canada    Montana           NaN             5
# 11         Enterprise  Canada    Montana           NaN             5
# 14         Enterprise  Canada    Montana           NaN             5
# 16         Government  Canada      Paseo           NaN            10
# ..                ...     ...        ...           ...           ...
# 652         Midmarket  Canada      Paseo          High            10
# 655         Midmarket  Canada      Paseo          High            10
# 669        Government  Canada        VTT          High           250
# 673        Enterprise  Canada        VTT          High           250
# 679        Government  Canada      Paseo          High            10
#
#      Units Sold  Sale Price  Gross Sales  Discounts      Sales      COGS  \
# ...

# %%
df['Country'].unique()
# Out:
# array(['Canada', 'Germany', 'France', 'Mexico',
#        'United States of America'], dtype=object)

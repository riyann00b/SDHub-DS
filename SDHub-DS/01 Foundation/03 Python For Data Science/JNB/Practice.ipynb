# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Dataset/my_file (1).csv', index_col='Rank')

df
# Out:
#        Peak All Time Peak     Actual gross Adjusted gross (in 2022 dollars)  \
# Rank
# 1         1             2     $780,000,000                     $780,000,000
# 2         1          7[2]     $579,800,000                     $579,800,000
# 3      1[4]          2[5]     $411,000,000                     $560,622,615
# 4      2[7]         10[7]     $397,300,000                     $454,751,555
# 5      2[4]           NaN     $345,675,146                     $402,844,849
# 6      2[4]         10[9]     $305,158,363                     $388,978,496
# 7     2[10]           NaN     $280,000,000                     $381,932,682
# 7       NaN           NaN     $257,600,000                     $257,600,000
# 9       NaN           NaN     $256,084,556                     $312,258,401
# 10      NaN           NaN     $250,400,000                     $309,141,878
# 11      NaN           NaN  $229,100,000[b]                     $283,202,896
# ...

# %%
df.shape
# Out:
# (20, 11)

# %%
df.columns.tolist()
# Out:
# ['Peak',
#  'All Time Peak',
#  'Actual\xa0gross',
#  'Adjusted\xa0gross (in 2022 dollars)',
#  'Artist',
#  'Tour title',
#  'Year(s)',
#  'Shows',
#  'Average gross',
#  'Ref.']

# %%
df['Artist'].value_counts()
# Out:
# Artist
# Taylor Swift    4
# Madonna         4
# Beyoncé         3
# Pink            3
# Lady Gaga       2
# Celine Dion     1
# Katy Perry      1
# Cher            1
# Adele           1
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Peak                                object
# All Time Peak                       object
# Actual gross                        object
# Adjusted gross (in 2022 dollars)    object
# Artist                              object
# Tour title                          object
# Year(s)                             object
# Shows                                int64
# Average gross                       object
# Ref.                                object
# dtype: object

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Peak                                55.0
# All Time Peak                       70.0
# Actual gross                         0.0
# Adjusted gross (in 2022 dollars)     0.0
# Artist                               0.0
# Tour title                           0.0
# Year(s)                              0.0
# Shows                                0.0
# Average gross                        0.0
# Ref.                                 0.0
# dtype: float64

# %%
dfc = df.copy()

# %%
dfc = dfc.drop('Peak', axis=1)
dfc = dfc.drop('All Time Peak', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 dfc = dfc.drop('Peak', axis=1)
#       2 dfc = dfc.drop('All Time Peak', axis=1)
#
# File ~/Desktop/SDHub-DS/SDHub-DS/01 Foundation/03 Python For Data Science/.venv/lib/python3.13/site-packages/pandas/core/frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
# ...

# %%
dfc
# Out:
#      All Time Peak  Actual gross Adjusted gross (in 2022 dollars)  \
# Rank
# 1                2  $780,000,000                     $780,000,000
# 2             7[2]  $579,800,000                     $579,800,000
# 3             2[5]  $411,000,000                     $560,622,615
# 4            10[7]  $397,300,000                     $454,751,555
# 5              NaN  $345,675,146                     $402,844,849
# 6            10[9]  $305,158,363                     $388,978,496
# 7              NaN  $280,000,000                     $381,932,682
# 14             NaN  $200,000,000                     $299,676,265
# 15             NaN  $194,000,000                     $281,617,035
#
#             Artist                                Tour title    Year(s)  \
# Rank
# 1     Taylor Swift                           The Eras Tour †  2023–2024
# 2          Beyoncé                    Renaissance World Tour       2023
# 3          Madonna               Sticky & Sweet Tour ‡[4][a]  2008–2009
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel('Financial Sample.xlsx')

df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %% [markdown]
# ## Time series analysis

# %%
# display total profit by year

df.groupby('Year')['Profit'].sum()
# Out:
# Year
# 2013     3878464.51
# 2014    13015237.75
# Name: Profit, dtype: float64

# %%
df.dtypes
# Out:
# Segment                        object
# Country                        object
# Product                        object
# Discount Band                  object
# Units Sold                    float64
# Manufacturing Price             int64
# Sale Price                      int64
# Gross Sales                   float64
# Discounts                     float64
#  Sales                        float64
# COGS                          float64
# Profit                        float64
# Date                   datetime64[ns]
# Month Number                    int64
# Month Name                     object
# Year                            int64
# dtype: object

# %%
df['Date'].dt.year
# Out:
# 0      2014
# 1      2014
# 2      2014
# 3      2014
# 4      2014
#        ...
# 695    2014
# 696    2014
# 697    2014
# 698    2014
# 699    2014
# Name: Date, Length: 700, dtype: int32

# %%
df['Product'].str.upper()
# Out:
# 0      CARRETERA
# 1      CARRETERA
# 2      CARRETERA
# 3      CARRETERA
# 4      CARRETERA
#          ...
# 695     AMARILLA
# 696     AMARILLA
# 697      MONTANA
# 698        PASEO
# 699          VTT
# Name: Product, Length: 700, dtype: object

# %%
import datetime

# %%
datetime.date.today()
# Out:
# datetime.date(2025, 8, 8)

# %%
datetime.date.today().year
# Out:
# 2025

# %%
datetime.date.today().month
# Out:
# 8

# %%
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df['New Year']=df['Date'].dt.year

df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
di = {'Name':['Uwaish','Husain','Aisha','Tyagi'],
      'Location':['Hyd','Goa','Mumbai','Sec'],
      'DOB':['01-02-2000','04-03-1999','10-10-1997','11-02-2002']}

df = pd.DataFrame(di)

df
# Out:
#      Name Location         DOB
# 0  Uwaish      Hyd  01-02-2000
# 1  Husain      Goa  04-03-1999
# 2   Aisha   Mumbai  10-10-1997
# 3   Tyagi      Sec  11-02-2002

# %%
df.dtypes
# Out:
# Name        object
# Location    object
# DOB         object
# dtype: object

# %%
df['DOB'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df['DOB'].dt.year
#
# File C:\sd.hub classes\python sd hub classes\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File C:\sd.hub classes\python sd hub classes\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
# add a new column which contain age of people in years

# %%
df.dtypes
# Out:
# Name        object
# Location    object
# DOB         object
# dtype: object

# %%
# change dob to date datatype

df['DOB'] = pd.to_datetime(df['DOB'])

# %%
df.dtypes
# Out:
# Name                object
# Location            object
# DOB         datetime64[ns]
# dtype: object

# %%
df['DOB'].dt.year
# Out:
# 0    2000
# 1    1999
# 2    1997
# 3    2002
# Name: DOB, dtype: int32

# %%
df['Today'] = datetime.date.today()

df
# Out:
#      Name Location        DOB       Today
# 0  Uwaish      Hyd 2000-01-02  2025-08-08
# 1  Husain      Goa 1999-04-03  2025-08-08
# 2   Aisha   Mumbai 1997-10-10  2025-08-08
# 3   Tyagi      Sec 2002-11-02  2025-08-08

# %%
df.dtypes
# Out:
# Name                object
# Location            object
# DOB         datetime64[ns]
# Today               object
# dtype: object

# %%
df['Today'] = pd.to_datetime(df['Today'])

df.dtypes
# Out:
# Name                object
# Location            object
# DOB         datetime64[ns]
# Today       datetime64[ns]
# dtype: object

# %%
df['Age'] = (df['Today'].dt.year) - (df['DOB'].dt.year)

df
# Out:
#      Name Location        DOB      Today  Age
# 0  Uwaish      Hyd 2000-01-02 2025-08-08   25
# 1  Husain      Goa 1999-04-03 2025-08-08   26
# 2   Aisha   Mumbai 1997-10-10 2025-08-08   28
# 3   Tyagi      Sec 2002-11-02 2025-08-08   23

# %%
# delete today column

df.drop(columns=['Today'],inplace=True)

# %%
df
# Out:
#      Name Location        DOB  Age
# 0  Uwaish      Hyd 2000-01-02   25
# 1  Husain      Goa 1999-04-03   26
# 2   Aisha   Mumbai 1997-10-10   28
# 3   Tyagi      Sec 2002-11-02   23

# %%
df['Age'].astype(float)
# Out:
# 0    25.0
# 1    26.0
# 2    28.0
# 3    23.0
# Name: Age, dtype: float64

# %%
df['Age'].astype(object)
# Out:
# 0    25
# 1    26
# 2    28
# 3    23
# Name: Age, dtype: object

# %%
df
# Out:
#      Name Location        DOB  Age
# 0  Uwaish      Hyd 2000-01-02   25
# 1  Husain      Goa 1999-04-03   26
# 2   Aisha   Mumbai 1997-10-10   28
# 3   Tyagi      Sec 2002-11-02   23

# %%
# rename columns

df.rename(columns={'Name':'First_Name','Age':'Age in Years'},inplace=True)

df
# Out:
#   First_Name Location        DOB  Age in Years
# 0     Uwaish      Hyd 2000-01-02            25
# 1     Husain      Goa 1999-04-03            26
# 2      Aisha   Mumbai 1997-10-10            28
# 3      Tyagi      Sec 2002-11-02            23

# %%
# display people born before 2000

df[(df['DOB'].dt.year>2000) & (df['DOB'].dt.year<2005)]
# Out:
#   First_Name Location        DOB  Age in Years
# 3      Tyagi      Sec 2002-11-02            23

# %%
# display born on 1st Ja

# %%
di = {'Email':['Uwaish@deloitte.com','Husain@gmail.com','Aisha@sdhub.in','Tyagi@gmail.com'],
      'Date':['01-02-2000','03-02-2000','05-02-2000','07-02-2000']}

df2 = pd.DataFrame(di)

df2
# Out:
#                  Email        Date
# 0  Uwaish@deloitte.com  01-02-2000
# 1     Husain@gmail.com  03-02-2000
# 2       Aisha@sdhub.in  05-02-2000
# 3      Tyagi@gmail.com  07-02-2000

# %%
df2[['Fname','Domain']] = df2['Email'].str.split('@',expand=True)

df2
# Out:
#                  Email        Date   Fname        Domain
# 0  Uwaish@deloitte.com  01-02-2000  Uwaish  deloitte.com
# 1     Husain@gmail.com  03-02-2000  Husain     gmail.com
# 2       Aisha@sdhub.in  05-02-2000   Aisha      sdhub.in
# 3      Tyagi@gmail.com  07-02-2000   Tyagi     gmail.com

# %%
df2[['Company','add']] = df2['Domain'].str.split('.',expand=True)

df2
# Out:
#                  Email        Date   Fname        Domain   Company  add
# 0  Uwaish@deloitte.com  01-02-2000  Uwaish  deloitte.com  deloitte  com
# 1     Husain@gmail.com  03-02-2000  Husain     gmail.com     gmail  com
# 2       Aisha@sdhub.in  05-02-2000   Aisha      sdhub.in     sdhub   in
# 3      Tyagi@gmail.com  07-02-2000   Tyagi     gmail.com     gmail  com

# %%
df2.drop(columns=['Domain','add'],inplace=True)

df2
# Out:
#                  Email        Date   Fname   Company
# 0  Uwaish@deloitte.com  01-02-2000  Uwaish  deloitte
# 1     Husain@gmail.com  03-02-2000  Husain     gmail
# 2       Aisha@sdhub.in  05-02-2000   Aisha     sdhub
# 3      Tyagi@gmail.com  07-02-2000   Tyagi     gmail

# %%
df2['Company'] = df2['Company'].str.title()

df2
# Out:
#                  Email        Date   Fname   Company
# 0  Uwaish@deloitte.com  01-02-2000  Uwaish  Deloitte
# 1     Husain@gmail.com  03-02-2000  Husain     Gmail
# 2       Aisha@sdhub.in  05-02-2000   Aisha     Sdhub
# 3      Tyagi@gmail.com  07-02-2000   Tyagi     Gmail
